# %% [markdown]
# # Изучение функций с помощью MatplotLib

# %%
import sys
sys.version_info
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# Цель задания - исследование функции
# $$\LARGE f(x) = \frac{x^{\beta} + \alpha^{\beta}}{x^{\beta} }$$
# при различных значениях $\alpha$ и $\beta$.
#
# Для каждой задачи необходимо:
#
# - Построить график (размер графика должен быть достаточным, чтобы визуально увидеть особенности изучаемых функций), график каждой функции должен быть одного цвета для одного значения $\alpha$ и $\beta$.
#
# - Подписать оси и заголовок
#
# - Создать легенду
#
# - Сохранить изображение в svg файл
#
# - Сделать и записать выводы о поведении графиков (можно использовать наводящие вопросы)
# ___________
#
# - Код не должен вызывать ошибки исполнения (например, из-за деления на 0 или корня из отрицательной величины)
#
# - Код должен выполняться (падение кода с ошибкой у проверяющего на python аналогичной версии - повод не зачесть все пункты соответствующей задачи)

# %% [markdown]
# ## Задача №1
#
# ### Часть 1
#
# Построить в общих осях графики для:
#
# - $\alpha = 1, \beta = 1$
#
# - $\alpha = 2, \beta = 1$
#
# - $\alpha = 1, \beta = 2$

# %%
x = np.linspace(-1000,1000,1000001)
fx_name = r'$f(x)=\frac{x^𝛽 + 𝛼^𝛽}{x^𝛽}$'
def func(x, 𝛼, 𝛽):
    with np.errstate(divide='ignore', invalid='ignore'):
        return (x ** 𝛽 + 𝛼 ** 𝛽) / x ** 𝛽


y1 = func(x, 1, 1)
y2 = func(x, 2, 1)
y3 = func(x, 1, 2)

# %%
fig, axes = plt.subplots(figsize=(13, 8))
axes.plot(x, y1, label='$𝛼=1, 𝛽=1$')
axes.plot(x, y2, label='$𝛼=2, 𝛽=1$')
axes.plot(x, y3, label='$𝛼=1, 𝛽=2$')
axes.legend()
axes.set_ybound(lower=-80, upper=80)
axes.set_xbound(lower=-6, upper=6)
axes.set_title(f'График функции {fx_name} при различных $𝛼$ и $𝛽$')
axes.set_xlabel('x', fontsize=16)
axes.set_ylabel('f(x)', fontsize=16)
plt.savefig('1_0.svg')

# %% [markdown]
# ### Часть 2
#
# Построить в общих осях графики для $x>0$.
#
# На том же графике сделать 2 врезки, демонстрирующие поведение графиков на 2 интервалах:
#
# - для малых x
#
# - для больших x
#
# Необходимо продемонстрировать возможность (или невозможность) пересечений и стремление функций.
#
# Цвет линий на врезках и основном графике должен быть одинаковым для одних и тех же значений $\alpha$ и $\beta$.

# %%
fig, axes = plt.subplots(figsize=(13, 8))
axes.plot(x, y1, label='$𝛼=1, 𝛽=1$')
axes.plot(x, y2, label='$𝛼=2, 𝛽=1$')
axes.plot(x, y3, label='$𝛼=1, 𝛽=2$')
axes.legend()
axes.set_ybound(lower=-80, upper=80)
axes.set_xbound(lower=-6, upper=6)
axes.set_title(f'График функции {fx_name} при различных $𝛼$ и $𝛽$')
axes.set_xlabel('x', fontsize=16)
axes.set_ylabel('f(x)', fontsize=16)
axes2 = fig.add_axes([0.2, 0.6, 0.2, 0.2])
axes2.set_title(f'График функции при больших x', fontsize=8)
axes2.plot(x, y1, label='$𝛼=1, 𝛽=1$')
axes2.plot(x, y2, label='$𝛼=2, 𝛽=1$')
axes2.plot(x, y3, label='$𝛼=1, 𝛽=2$')
axes2.legend()
axes2.set_ybound(lower=0.99, upper=1.05)
axes2.set_xbound(lower=100, upper=1000)
axes3 = fig.add_axes([0.6, 0.2, 0.2, 0.2])
axes3.plot(x, y1, label='$𝛼=1, 𝛽=1$')
axes3.plot(x, y2, label='$𝛼=2, 𝛽=1$')
axes3.plot(x, y3, label='$𝛼=1, 𝛽=2$')
axes3.set_ybound(lower=0, upper=7)
axes3.set_xbound(lower=0, upper=2)
axes3.set_title(f'График функции при малых x', fontsize=8)
axes3.legend()
plt.savefig('1_1.svg')

# %% [markdown]
# ### Часть 3
#
# Построить в общих осях графики для $x<0$.
#
# На том же графике сделать 1 врезку, демонстрирующую поведение графиков при удалении x от 0 к $-\infty$.
#
# Необходимо продемонстрировать возможность (или невозможность) пересечений и стремление функций. Так же нанесите на графики прямую f(x) = 0.
#
# Цвет линий на врезках и основном графике должен быть одинаковым для одних и тех же значений $\alpha$ и $\beta$.

# %%
x = np.linspace(-1000,0,100001)
x2 = np.linspace(-1000,1,100001)
fx_name = r'$f(x)=\frac{x^𝛽 + 𝛼^𝛽}{x^𝛽}$'
def func(x, 𝛼, 𝛽):
    with np.errstate(divide='ignore', invalid='ignore'):
        return (x ** 𝛽 + 𝛼 ** 𝛽) / x ** 𝛽
def f0(x):
    return x*0

y1 = func(x, 1, 1)
y2 = func(x, 2, 1)
y3 = func(x, 1, 2)
y4 = f0(x2)
fig, axes = plt.subplots(figsize=(13, 8))
axes.plot(x, y1, label='$𝛼=1, 𝛽=1$')
axes.plot(x, y2, label='$𝛼=2, 𝛽=1$')
axes.plot(x, y3, label='$𝛼=1, 𝛽=2$')
axes.plot(x2, y4, label='f(x)=0')
axes.legend()
axes.set_ybound(lower=-80, upper=80)
axes.set_xbound(lower=-6, upper=1)
axes.set_title(f'График функции {fx_name} при различных $𝛼$ и $𝛽$')
axes.set_xlabel('x', fontsize=16)
axes.set_ylabel('f(x)', fontsize=16)
axes2 = fig.add_axes([0.2, 0.6, 0.25, 0.25])
axes2.set_title(f'График функции при x -> -$∞$', fontsize=8)
axes2.plot(x, y1, label='$𝛼=1, 𝛽=1$')
axes2.plot(x, y2, label='$𝛼=2, 𝛽=1$')
axes2.plot(x, y3, label='$𝛼=1, 𝛽=2$')
axes2.plot(x2, y4, label='f(x)=0')
axes2.set_ybound(lower=0.95, upper=1.01)
axes2.set_xbound(lower=-1000, upper=-99)
axes2.legend()
axes3 = fig.add_axes([0.2, 0.2, 0.25, 0.25])
axes3.plot(x, y1, label='$𝛼=1, 𝛽=1$')
axes3.plot(x, y2, label='$𝛼=2, 𝛽=1$')
axes3.plot(x, y3, label='$𝛼=1, 𝛽=2$')
axes3.plot(x2, y4, label='f(x)=0')
axes3.legend()

axes3.set_ybound(lower=-5, upper=3)
axes3.set_xbound(lower=-3, upper=0)
axes3.set_title(f'График функции при малых x', fontsize=8)
plt.savefig('1_2.svg')

# %% [markdown]
# Сделайте выводы о поведении графиков при различных значениях $\alpha$ и $\beta$.
#
# Изучите возможности пересечения и то к чему стремятся кривые.
#
# Сделайте выводы о возрастании/убывании.

# %% [markdown]
# Поведение при различных 𝛼=1, 𝛽=1 и 𝛼=2, 𝛽=1 одинакова.
# 𝛼=1, 𝛽=2 меняет поведение функции при x -> 0 слева от оси координат.
# 𝛼=1, 𝛽=2 пересекает ось абсцисс при х= -1.0,
# 𝛼=2, 𝛽=1 пересекает ось абсцисс при х= -2.0,
# При х-> −∞ и +∞ графики стремятся к 1.
# Точки пересечения: (1.0, 2,0) и (0.5, 5)

# %% [markdown]
# ## Задача №2
#
# Построить в общих осях графики для:
#
# - $\alpha = 1, \beta = 0$
#
# - $\alpha = 0, \beta = 0$
#
# - $\alpha = 0, \beta = 1$
#
# - $\alpha = 0, \beta = 2$
#
# - $\alpha = 1, \beta = -1$
#
# - $\alpha = 2, \beta = -1$
#
# Сделайте выводы о поведении графиков

# %%
x = np.linspace(-100,100,10001)
x2 = np.linspace(-100,99,10001)
fx_name = r'$f(x)=\frac{x^𝛽 + 𝛼^𝛽}{x^𝛽}$'
def func(x, 𝛼, 𝛽):
    with np.errstate(divide='ignore', invalid='ignore'):
        return (x ** 𝛽 + 𝛼 ** 𝛽) / x ** 𝛽


y1 = func(x, 1, 0)
y2 = func(x, 0, 0)
y3 = func(x, 0, 1)
y4 = func(x, 0, 2)
y5 = func(x, 1, -1)
y6 = func(x, 2, -1)

# %%
fig, axes = plt.subplots(figsize=(13, 8))
axes.plot(x, y1, label='$𝛼=1, 𝛽=0$')
axes.plot(x2, y2, label='$𝛼=0, 𝛽=0$')
axes.plot(x, y3, label='$𝛼=0, 𝛽=1$')
axes.plot(x2, y4, label='$𝛼=0, 𝛽=2$')
axes.plot(x, y5, label='$𝛼=1, 𝛽=-1$')
axes.plot(x, y6, label='$𝛼=2, 𝛽=-1$')
axes.legend()
axes.set_ybound(lower=-80, upper=80)
axes.set_xbound(lower=-100, upper=100)
axes.set_title(f'График функции {fx_name} при различных $𝛼$ и $𝛽$')
axes.set_xlabel('x', fontsize=16)
axes.set_ylabel('f(x)', fontsize=16)
axes2 = fig.add_axes([0.3, 0.55, 0.2, 0.3])
axes2.set_title(f'График функции при больших x', fontsize=8)
axes2.plot(x, y1, label='$𝛼=1, 𝛽=0$')
axes2.plot(x2, y2, label='$𝛼=0, 𝛽=0$')
axes2.plot(x, y3, label='$𝛼=0, 𝛽=1$')
axes2.plot(x2, y4, label='$𝛼=0, 𝛽=2$')
axes2.plot(x, y5, label='$𝛼=1, 𝛽=-1$')
axes2.plot(x, y6, label='$𝛼=2, 𝛽=-1$')
axes2.legend(fontsize=6)
axes2.set_ybound(lower=-0.9, upper=2.5)
axes2.set_xbound(lower=98, upper=100)
axes3 = fig.add_axes([0.55, 0.15, 0.3, 0.3])
axes3.plot(x, y1, label='$𝛼=1, 𝛽=0$')
axes3.plot(x2, y2, label='$𝛼=0, 𝛽=0$')
axes3.plot(x, y3, label='$𝛼=0, 𝛽=1$')
axes3.plot(x2, y4, label='$𝛼=0, 𝛽=2$')
axes3.plot(x, y5, label='$𝛼=1, 𝛽=-1$')
axes3.plot(x, y6, label='$𝛼=2, 𝛽=-1$')
axes3.legend(fontsize=6)
axes3.set_ybound(lower=-2, upper=6)
axes3.set_xbound(lower=-2, upper=5)
axes3.set_title(f'График функции при малых x', fontsize=8)
plt.savefig('2_0.svg')

# %% [markdown]
# Все графики - прямые линии
# Накладываются друг на друга:
#    1) 𝛼=1,𝛽=0 и 𝛼=0,𝛽=0,
#    2) 𝛼=0,𝛽=1 и 𝛼=0,𝛽=2.
# 𝛼=1,𝛽=−1 и 𝛼=2,𝛽=−1 - пересекаются с 𝛼=0,𝛽=1 и 𝛼=0,𝛽=2 в точке (0.0, 1.0)
# 𝛼=1,𝛽=−1 пересекает 𝛼=1,𝛽=0 и 𝛼=0,𝛽=0 в точке (1.0, 2.0)
# 𝛼=2,𝛽=−1 пересекает 𝛼=1,𝛽=0 и 𝛼=0,𝛽=0 в точке (2.0, 2.0)

# %% [markdown]
# ## Задача №3
#
# Построить в общих осях графики для:
#
# - $\alpha = 1, \beta = 0.5$
#
# - $\alpha = 1, \beta = -0.5$
#
# - $\alpha = 1, \beta = -1.5$
#
# Сделайте выводы о поведении графиков, включая возрастание/убывание и выпуклость/вогнутость

# %%
x = np.linspace(-1000,1000,1000001)
fx_name = r'$f(x)=\frac{x^𝛽 + 𝛼^𝛽}{x^𝛽}$'
def func(x, 𝛼, 𝛽):
    with np.errstate(divide='ignore', invalid='ignore'):
        return (np.power(x, 𝛽) + np.power(𝛼, 𝛽)) / np.power(x, 𝛽)


y1 = func(x, 1, 0.5)
y2 = func(x, 1, -0.5)
y3 = func(x, 1, -1.5)
fig, axes = plt.subplots(figsize=(13, 8))
axes.plot(x, y1, label='$𝛼=1, 𝛽=0.5$')
axes.plot(x, y2, label='$𝛼=1, 𝛽=-0.5$')
axes.plot(x, y3, label='$𝛼=1, 𝛽=-1.5$')
axes.legend()
axes.set_ybound(lower=-2, upper=50)
axes.set_xbound(lower=-2, upper=60)
axes.set_title(f'График функции {fx_name} при различных $𝛼$ и $𝛽$')
axes.set_xlabel('x', fontsize=16)
axes.set_ylabel('f(x)', fontsize=16)

axes3 = fig.add_axes([0.5, 0.4, 0.3, 0.3])
axes3.plot(x, y1, label='$𝛼=1, 𝛽=0.5$')
axes3.plot(x, y2, label='$𝛼=1, 𝛽=-0.5$')
axes3.plot(x, y3, label='$𝛼=1, 𝛽=-1.5$')
axes3.legend(fontsize=6)
axes3.set_ybound(lower=0, upper=4)
axes3.set_xbound(lower=-1, upper=4)
axes3.set_title(f'График функции при малых x', fontsize=8)
plt.savefig('3_0.svg')

# %% [markdown]
# Графики пересекаются в точке (1.0, 2.0).
# график функции с 𝛼=1, 𝛽=0.5 - убывающий, вогнутый
# график функции с 𝛼=1, 𝛽=-0.5 - возрастающий, выпуклый
# график функции с 𝛼=1, 𝛽=-1.5 - возрастающий, вогнутый

# %% [markdown]
# ## Задача №4
#
# В результате выполнения предыдущей задачи, вы вероятно заметите, что все графики с $\alpha=1$ проходят через общую точку (1, 2).
#
# Постройте в одном ряду 3 графика, чтобы убедиться в выводах, сделанных по результатам предыдущей задачи.
#
# Каждый график будет содержать 4 кривые. 2 общих:
#
# - $\alpha = 1, \beta = 0$ (в качестве цвета попробуйте использовать 'b--')
#
# - $\alpha = 1, \beta = -1$ (в качестве цвета попробуйте использовать 'r--')
#
# И 2 уникальных для каждого графика:
#
# 1. $\alpha = 1, \beta = 0.5$ и $\alpha = 1, \beta = 0.8$
#
# 2. $\alpha = 1, \beta = -0.5$ и $\alpha = 1, \beta = -0.8$
#
# 3. $\alpha = 1, \beta = -1.5$ и $\alpha = 1, \beta = -2.5$
#
# Не забудьте добавить легенду на каждый график. Для этого может потребоваться вызвать метод legend() для каждого объекта осей.
#
# Для того чтобы задать общий заголовок для всех 3 графиков используйте метод https://matplotlib.org/api/_as_gen/matplotlib.pyplot.suptitle.html

# %%
x = np.linspace(-1000,1000,1000001)
fx_name = r'$f(x)=\frac{x^𝛽 + 𝛼^𝛽}{x^𝛽}$'
def func(x, 𝛼, 𝛽):
    with np.errstate(divide='ignore', invalid='ignore'):
        return (np.power(x, 𝛽) + pow(𝛼, 𝛽)) / np.power(x, 𝛽)
def func2(x, 𝛼, 𝛽):
    with np.errstate(divide='ignore', invalid='ignore'):
        return (np.power(x, 𝛽) + np.power(𝛼, 𝛽)) / np.power(x, 𝛽)


y1 = func(x, 1, 0)
y2 = func(x, 1, -1)
y11 = func(x, 1, 0.5)
y12 = func(x, 1, 0.8)
y21 = func2(x, 1, -0.5)
y22 = func2(x, 1, -0.8)
y31 = func2(x, 1, -1.5)
y32 = func2(x, 1, -2.5)
fig, axes = plt.subplots(1,3, figsize=(13, 8))
axes[0].plot(x, y1, label='$𝛼=1, 𝛽=0$', color='blue')
axes[0].plot(x, y2, label='$𝛼=1, 𝛽=-1$', color='red')
axes[0].plot(x, y11, label='$𝛼=1, 𝛽=0.5$')
axes[0].plot(x, y12, label='$𝛼=1, 𝛽=0.8$')
axes[0].set_ybound(lower=-3, upper=10)
axes[0].set_xbound(lower=-2, upper=5)
axes[0].legend(loc=[0.4, 0.8])
axes[0].set_xlabel('x', fontsize=10)
axes[0].set_ylabel('f(x)', fontsize=10)
axes[1].plot(x, y1, label='$𝛼=1, 𝛽=0$', color='blue')
axes[1].plot(x, y2, label='$𝛼=1, 𝛽=-1$', color='red')
axes[1].plot(x, y21, label='$𝛼=1, 𝛽=-0.5$')
axes[1].plot(x, y22, label='$𝛼=1, 𝛽=-0.8$')
axes[1].set_ybound(lower=-3, upper=10)
axes[1].set_xbound(lower=-2, upper=5)
axes[1].legend(loc=[0.4, 0.8])
axes[1].set_xlabel('x', fontsize=10)
axes[1].set_ylabel('f(x)', fontsize=10)
axes[2].plot(x, y1, label='$𝛼=1, 𝛽=0$', color='blue')
axes[2].plot(x, y2, label='$𝛼=1, 𝛽=-1$', color='red')
axes[2].plot(x, y21, label='$𝛼=1, 𝛽=-1.5$')
axes[2].plot(x, y22, label='$𝛼=1, 𝛽=-2.5$')
axes[2].set_ybound(lower=-3, upper=10)
axes[2].set_xbound(lower=-2, upper=5)
axes[2].legend(loc=[0.4, 0.8])
axes[2].set_xlabel('x', fontsize=10)
axes[2].set_ylabel('f(x)', fontsize=10)
plt.suptitle(f'График функции {fx_name} при $𝛼$=1 и различных и $𝛽$')
plt.savefig('4_0.svg')

# %% [markdown]
# Все графики вида 𝑓(𝑥)=(𝑥**𝛽 + 𝛼**𝛽)/𝑥**𝛽 с 𝛼=1 проходят через точку (1.0, 2.0) не зависимо от 𝛽
